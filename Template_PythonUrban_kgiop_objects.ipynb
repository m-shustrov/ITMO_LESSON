# %% [markdown]
# # Шустров Максим Валерьевич

# %% [markdown]
# # Улицы. Объекты культурного наследия. Невского района

# %% [markdown]
# ## PIP, Import, Константы, Функции

# %% [markdown]
# ### PIP модулей

# %%
# todo собрать установку всех необходимых модулей в одном месте
# !pip install folium -U
# !pip install geopandas mapclassify osmnx
# Out:
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# Requirement already satisfied: folium in /usr/local/lib/python3.7/dist-packages (0.12.1.post1)
# Requirement already satisfied: numpy in /usr/local/lib/python3.7/dist-packages (from folium) (1.21.6)
# Requirement already satisfied: jinja2>=2.9 in /usr/local/lib/python3.7/dist-packages (from folium) (2.11.3)
# Requirement already satisfied: requests in /usr/local/lib/python3.7/dist-packages (from folium) (2.28.1)
# Requirement already satisfied: branca>=0.3.0 in /usr/local/lib/python3.7/dist-packages (from folium) (0.5.0)
# Requirement already satisfied: MarkupSafe>=0.23 in /usr/local/lib/python3.7/dist-packages (from jinja2>=2.9->folium) (2.0.1)
# Requirement already satisfied: idna<4,>=2.5 in /usr/local/lib/python3.7/dist-packages (from requests->folium) (2.10)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.7/dist-packages (from requests->folium) (2022.6.15)
# Requirement already satisfied: urllib3<1.27,>=1.21.1 in /usr/local/lib/python3.7/dist-packages (from requests->folium) (1.24.3)
# Requirement already satisfied: charset-normalizer<3,>=2 in /usr/local/lib/python3.7/dist-packages (from requests->folium) (2.1.0)
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# Requirement already satisfied: geopandas in /usr/local/lib/python3.7/dist-packages (0.10.2)
# Requirement already satisfied: mapclassify in /usr/local/lib/python3.7/dist-packages (2.4.3)
# Requirement already satisfied: osmnx in /usr/local/lib/python3.7/dist-packages (1.1.2)
# Requirement already satisfied: shapely>=1.6 in /usr/local/lib/python3.7/dist-packages (from geopandas) (1.8.2)
# Requirement already satisfied: pyproj>=2.2.0 in /usr/local/lib/python3.7/dist-packages (from geopandas) (3.2.1)
# Requirement already satisfied: pandas>=0.25.0 in /usr/local/lib/python3.7/dist-packages (from geopandas) (1.3.5)
# Requirement already satisfied: fiona>=1.8 in /usr/local/lib/python3.7/dist-packages (from geopandas) (1.8.21)
# Requirement already satisfied: cligj>=0.5 in /usr/local/lib/python3.7/dist-packages (from fiona>=1.8->geopandas) (0.7.2)
# Requirement already satisfied: click>=4.0 in /usr/local/lib/python3.7/dist-packages (from fiona>=1.8->geopandas) (7.1.2)
# Requirement already satisfied: attrs>=17 in /usr/local/lib/python3.7/dist-packages (from fiona>=1.8->geopandas) (21.4.0)
# Requirement already satisfied: six>=1.7 in /usr/local/lib/python3.7/dist-packages (from fiona>=1.8->geopandas) (1.15.0)
# Requirement already satisfied: munch in /usr/local/lib/python3.7/dist-packages (from fiona>=1.8->geopandas) (2.5.0)
# Requirement already satisfied: setuptools in /usr/local/lib/python3.7/dist-packages (from fiona>=1.8->geopandas) (57.4.0)
# Requirement already satisfied: certifi in /usr/local/lib/python3.7/dist-packages (from fiona>=1.8->geopandas) (2022.6.15)
# Requirement already satisfied: click-plugins>=1.0 in /usr/local/lib/python3.7/dist-packages (from fiona>=1.8->geopandas) (1.1.1)
# Requirement already satisfied: python-dateutil>=2.7.3 in /usr/local/lib/python3.7/dist-packages (from pandas>=0.25.0->geopandas) (2.8.2)
# Requirement already satisfied: pytz>=2017.3 in /usr/local/lib/python3.7/dist-packages (from pandas>=0.25.0->geopandas) (2022.1)
# Requirement already satisfied: numpy>=1.17.3 in /usr/local/lib/python3.7/dist-packages (from pandas>=0.25.0->geopandas) (1.21.6)
# Requirement already satisfied: scipy>=1.0 in /usr/local/lib/python3.7/dist-packages (from mapclassify) (1.7.3)
# Requirement already satisfied: scikit-learn in /usr/local/lib/python3.7/dist-packages (from mapclassify) (1.0.2)
# Requirement already satisfied: networkx in /usr/local/lib/python3.7/dist-packages (from mapclassify) (2.6.3)
# Requirement already satisfied: requests>=2.26 in /usr/local/lib/python3.7/dist-packages (from osmnx) (2.28.1)
# Requirement already satisfied: matplotlib>=3.4 in /usr/local/lib/python3.7/dist-packages (from osmnx) (3.5.2)
# Requirement already satisfied: Rtree>=0.9 in /usr/local/lib/python3.7/dist-packages (from osmnx) (1.0.0)
# Requirement already satisfied: pyparsing>=2.2.1 in /usr/local/lib/python3.7/dist-packages (from matplotlib>=3.4->osmnx) (3.0.9)
# Requirement already satisfied: fonttools>=4.22.0 in /usr/local/lib/python3.7/dist-packages (from matplotlib>=3.4->osmnx) (4.34.4)
# Requirement already satisfied: packaging>=20.0 in /usr/local/lib/python3.7/dist-packages (from matplotlib>=3.4->osmnx) (21.3)
# Requirement already satisfied: kiwisolver>=1.0.1 in /usr/local/lib/python3.7/dist-packages (from matplotlib>=3.4->osmnx) (1.4.3)
# Requirement already satisfied: pillow>=6.2.0 in /usr/local/lib/python3.7/dist-packages (from matplotlib>=3.4->osmnx) (7.1.2)
# Requirement already satisfied: cycler>=0.10 in /usr/local/lib/python3.7/dist-packages (from matplotlib>=3.4->osmnx) (0.11.0)
# Requirement already satisfied: typing-extensions in /usr/local/lib/python3.7/dist-packages (from kiwisolver>=1.0.1->matplotlib>=3.4->osmnx) (4.1.1)
# Requirement already satisfied: idna<4,>=2.5 in /usr/local/lib/python3.7/dist-packages (from requests>=2.26->osmnx) (2.10)
# Requirement already satisfied: urllib3<1.27,>=1.21.1 in /usr/local/lib/python3.7/dist-packages (from requests>=2.26->osmnx) (1.24.3)
# Requirement already satisfied: charset-normalizer<3,>=2 in /usr/local/lib/python3.7/dist-packages (from requests>=2.26->osmnx) (2.1.0)
# Requirement already satisfied: threadpoolctl>=2.0.0 in /usr/local/lib/python3.7/dist-packages (from scikit-learn->mapclassify) (3.1.0)
# Requirement already satisfied: joblib>=0.11 in /usr/local/lib/python3.7/dist-packages (from scikit-learn->mapclassify) (1.1.0)

# %% [markdown]
# ### Import модулей

# %%
# todo собрать импорты всех модулей в одном месте
import pandas as pd
import geopandas as gpd
import osmnx as ox

# %% [markdown]
# ### КОНСТАНТЫ

# %%
# Подложка карт. Выбрана "CartoDB positron", по умолчанию “OpenStreetMap” 
TILES = "CartoDB positron"

# Данные, с которыми будет работа. Район, улицы, памятники истоии и культуры
TERRITORY_NAME = 'Невский район, Санкт-Петербург'
STREETS_FILE_URL = "https://drive.google.com/file/d/1bUT1E-QSbG1vpSNM2dOG2-LEVXSrPdo3/view?usp=sharing"
KGIOP_FILE_URL = "https://raw.githubusercontent.com/m-shustrov/ITMO_LESSON/main/kgiop_objects.geojson"

STREET_BUFFER = 100 # Применяется для буфера улиц

# %% [markdown]
# ### Функции

# %%
def get_google_drive_download_url(url: str) -> str:
    """
    Функция возвращает ссылку для скачивания с google drive.
     Например: "https://drive.google.com/file/d/1MWGOuqV76e0ubQOg8Ke0KTU3yGpkprHp/view?usp=sharing" ->
     "https://drive.google.com/uc?export=download&id=1MWGOuqV76e0ubQOg8Ke0KTU3yGpkprHp"
    """
    drive_id = url.split("/")[5]
    return f"https://drive.google.com/uc?export=download&id={drive_id}"

# %% [markdown]
# ## Территория

# %% [markdown]
# ### Загрузка территории из OSM (Extract), Невский район СПб

# %%
territory = ox.geocode_to_gdf(TERRITORY_NAME)  # подгружаем с OSM и получаем GeoDataFrame
territory.explore(tiles = TILES)
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;head&gt;
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#
#         &lt;script&gt;
#             L_NO_TOUCH = false;
#             L_DISABLE_3D = false;
#         &lt;/script&gt;
#
#     &lt;style&gt;html, body {width: 100%;height: 100%;margin: 0;padding: 0;}&lt;/style&gt;
#     &lt;style&gt;#map {position:absolute;top:0;bottom:0;right:0;left:0;}&lt;/style&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.6.0/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-1.12.4.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://maxcdn.bootstrapcdn.com/bootstrap/3.2.0/js/bootstrap.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.6.0/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://maxcdn.bootstrapcdn.com/bootstrap/3.2.0/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://maxcdn.bootstrapcdn.com/bootstrap/3.2.0/css/bootstrap-theme.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://maxcdn.bootstrapcdn.com/font-awesome/4.6.3/css/font-awesome.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_88f279ab59b7cdbbf247e4bcee5d2b7e {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#             &lt;/style&gt;
#
#
#                     &lt;style&gt;
#                         .foliumtooltip {
#
#                         }
#                        .foliumtooltip table{
#                             margin: auto;
#                         }
#                         .foliumtooltip tr{
#                             text-align: left;
#                         }
#                         .foliumtooltip th{
#                             padding: 2px; padding-right: 8px;
#                         }
#                     &lt;/style&gt;
#
# &lt;/head&gt;
# &lt;body&gt;
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_88f279ab59b7cdbbf247e4bcee5d2b7e&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#             var map_88f279ab59b7cdbbf247e4bcee5d2b7e = L.map(
#                 &quot;map_88f279ab59b7cdbbf247e4bcee5d2b7e&quot;,
#                 {
#                     center: [59.8719823, 30.465238149999998],
#                     crs: L.CRS.EPSG3857,
#                     zoom: 10,
#                     zoomControl: true,
#                     preferCanvas: false,
#                 }
#             );
#             L.control.scale().addTo(map_88f279ab59b7cdbbf247e4bcee5d2b7e);
#
#
#
#
#
#             var tile_layer_292a3c22bd11a4120c2628fca18b2343 = L.tileLayer(
#                 &quot;https://cartodb-basemaps-{s}.global.ssl.fastly.net/light_all/{z}/{x}/{y}.png&quot;,
#                 {&quot;attribution&quot;: &quot;\u0026copy; \u003ca href=\&quot;http://www.openstreetmap.org/copyright\&quot;\u003eOpenStreetMap\u003c/a\u003e contributors \u0026copy; \u003ca href=\&quot;http://cartodb.com/attributions\&quot;\u003eCartoDB\u003c/a\u003e, CartoDB \u003ca href =\&quot;http://cartodb.com/attributions\&quot;\u003eattributions\u003c/a\u003e&quot;, &quot;detectRetina&quot;: false, &quot;maxNativeZoom&quot;: 18, &quot;maxZoom&quot;: 18, &quot;minZoom&quot;: 0, &quot;noWrap&quot;: false, &quot;opacity&quot;: 1, &quot;subdomains&quot;: &quot;abc&quot;, &quot;tms&quot;: false}
#             ).addTo(map_88f279ab59b7cdbbf247e4bcee5d2b7e);
#
#
#             map_88f279ab59b7cdbbf247e4bcee5d2b7e.fitBounds(
#                 [[59.8077721, 30.3633101], [59.9361925, 30.5671662]],
#                 {}
#             );
#
#
#         function geo_json_2cb43452c03e646a26943a12630b5afa_styler(feature) {
#             switch(feature.id) {
#                 default:
#                     return {&quot;fillOpacity&quot;: 0.5, &quot;weight&quot;: 2};
#             }
#         }
#         function geo_json_2cb43452c03e646a26943a12630b5afa_highlighter(feature) {
#             switch(feature.id) {
#                 default:
#                     return {&quot;fillOpacity&quot;: 0.75};
#             }
#         }
#         function geo_json_2cb43452c03e646a26943a12630b5afa_pointToLayer(feature, latlng) {
#             var opts = {&quot;bubblingMouseEvents&quot;: true, &quot;color&quot;: &quot;#3388ff&quot;, &quot;dashArray&quot;: null, &quot;dashOffset&quot;: null, &quot;fill&quot;: true, &quot;fillColor&quot;: &quot;#3388ff&quot;, &quot;fillOpacity&quot;: 0.2, &quot;fillRule&quot;: &quot;evenodd&quot;, &quot;lineCap&quot;: &quot;round&quot;, &quot;lineJoin&quot;: &quot;round&quot;, &quot;opacity&quot;: 1.0, &quot;radius&quot;: 2, &quot;stroke&quot;: true, &quot;weight&quot;: 3};
#
#             let style = geo_json_2cb43452c03e646a26943a12630b5afa_styler(feature)
#             Object.assign(opts, style)
#
#             return new L.CircleMarker(latlng, opts)
#         }
#
#         function geo_json_2cb43452c03e646a26943a12630b5afa_onEachFeature(feature, layer) {
#             layer.on({
#                 mouseout: function(e) {
#                     if(typeof e.target.setStyle === &quot;function&quot;){
#                         geo_json_2cb43452c03e646a26943a12630b5afa.resetStyle(e.target);
#                     }
#                 },
#                 mouseover: function(e) {
#                     if(typeof e.target.setStyle === &quot;function&quot;){
#                         const highlightStyle = geo_json_2cb43452c03e646a26943a12630b5afa_highlighter(e.target.feature)
#                         e.target.setStyle(highlightStyle);
#                     }
#                 },
#             });
#         };
#         var geo_json_2cb43452c03e646a26943a12630b5afa = L.geoJson(null, {
#                 onEachFeature: geo_json_2cb43452c03e646a26943a12630b5afa_onEachFeature,
#
#                 style: geo_json_2cb43452c03e646a26943a12630b5afa_styler,
#                 pointToLayer: geo_json_2cb43452c03e646a26943a12630b5afa_pointToLayer
#         });
#
#         function geo_json_2cb43452c03e646a26943a12630b5afa_add (data) {
#             geo_json_2cb43452c03e646a26943a12630b5afa
#                 .addData(data)
#                 .addTo(map_88f279ab59b7cdbbf247e4bcee5d2b7e);
#         }
#             geo_json_2cb43452c03e646a26943a12630b5afa_add({&quot;bbox&quot;: [30.3633101, 59.8077721, 30.5671662, 59.9361925], &quot;features&quot;: [{&quot;bbox&quot;: [30.3633101, 59.8077721, 30.5671662, 59.9361925], &quot;geometry&quot;: {&quot;coordinates&quot;: [[[30.3633101, 59.9138661], [30.3634988, 59.9133713], [30.3642898, 59.9119928], [30.3650093, 59.9112422], [30.3653961, 59.9108797], [30.3659803, 59.9104435], [30.3665334, 59.9100944], [30.3701382, 59.9080907], [30.3747757, 59.9053905], [30.3775948, 59.9034964], [30.3796976, 59.9020492], [30.3819614, 59.9003597], [30.3870576, 59.8967599], [30.3908449, 59.8939993], [30.3902012, 59.8937948], [30.390523, 59.8935633], [30.3911238, 59.8937571], [30.39195, 59.893

# %% [markdown]
# ### Обработка данных с территорией (Transform)

# %%
# Удаляем все столбцы (кроме столбца geometry). Добавляем столбец "Название территории" 
territory.drop(territory.columns.difference(['geometry']), 1, inplace=True) 
territory["Название территории"] = "Невский район"
territory
# Out:
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:2: FutureWarning: In a future version of pandas all arguments of DataFrame.drop except for the argument 'labels' will be keyword-only
#                                             geometry Название территории
# 0  POLYGON ((30.36331 59.91387, 30.36350 59.91337...       Невский район

# %% [markdown]
# ## Улицы

# %% [markdown]
# ### Загрузка файла с улицами из google disk (Extract)

# %%
url = get_google_drive_download_url(STREETS_FILE_URL)
gdf_streets = gpd.read_file(url, mask=territory)  # Отфильтровываем улицы по маске геометрии территории полученной ранее
gdf_streets
# Out:
#      type         id                                               tags  \
# 0     way    4454554  {'foot': 'no', 'hgv': 'no', 'highway': 'tertia...
# 1     way    4455612  {'addr:postcode': '193318', 'highway': 'tertia...
# 2     way    4456145  {'foot': 'no', 'highway': 'primary', 'lanes': ...
# 3     way    4456665  {'foot': 'no', 'highway': 'secondary', 'lanes'...
# 4     way    4456737  {'foot': 'no', 'highway': 'primary', 'lanes': ...
# ...   ...        ...                                                ...
# 8923  way  982174776       {'highway': 'service', 'surface': 'unpaved'}
# 8924  way  983845877  {'highway': 'service', 'service': 'parking_ais...
# 8925  way  983845878  {'highway': 'service', 'service': 'parking_ais...
# 8926  way  983845879  {'highway': 'service', 'service': 'parking_ais...
# 8927  way  983845880  {'highway': 'service', 'service': 'parking_ais...
#
#                                                geometry
# 0     LINESTRING (3391641.514 8369024.600, 3391686.0...
# 1     LINESTRING (3388065.876 8383198.675, 3388058.2...
# 2     LINESTRING (3391979.892 8382039.064, 3391986.1...
# 3     LINESTRING (3381745.367 8378798.756, 3381756.9...
# 4     LINESTRING (3391760.525 8382110.538, 3391738.0...
# ...                                                 ...
# 8923  LINESTRING (3387171.491 8370639.425, 3387147.9...
# 8924  LINESTRING (3390005.551 8377847.117, 3389996.3...
# 8925  LINESTRING (3389872.625 8377858.460, 3389955.5...
# 8926  LINESTRING (3389876.755 8377827.961, 3389973.3...
# 8927  LINESTRING (3389880.050 8377807.561, 3389985.5...
#
# [8928 rows x 4 columns]

# %% [markdown]
# ### Обработка данных с улицами (Transform)

# %%
#json_normalize позволяет преобразовать вложенные структуры данных в json файле с таблицу
tags = pd.json_normalize(gdf_streets["tags"])
tags
# Out:
#      foot  hgv    highway lanes  lit  maxspeed                 name  \
# 0      no   no   tertiary     2  yes  RU:urban        улица Чернова
# 1     NaN  NaN   tertiary     2  yes  RU:urban        Зольная улица
# 2      no  NaN    primary     5  yes  RU:urban  Российский проспект
# 3      no  NaN  secondary     1  yes  RU:urban  Глухоозёрское шоссе
# 4      no  NaN    primary     3  yes  RU:urban                  NaN
# ...   ...  ...        ...   ...  ...       ...                  ...
# 8923  NaN  NaN    service   NaN  NaN       NaN                  NaN
# 8924  NaN  NaN    service   NaN  NaN       NaN                  NaN
# 8925  NaN  NaN    service   NaN  NaN       NaN                  NaN
# 8926  NaN  NaN    service   NaN  NaN       NaN                  NaN
# 8927  NaN  NaN    service   NaN  NaN       NaN                  NaN
#
#               name:en postal_code  surface  ... maxspeed:forward construction  \
# 0     Chernova Street      192012  asphalt  ...              NaN          NaN
# 1                 NaN         NaN  asphalt  ...              NaN          NaN
# 2                 NaN         NaN  asphalt  ...              NaN          NaN
# 3                 NaN         NaN  asphalt  ...              NaN          NaN
# 4                 NaN         NaN  asphalt  ...              NaN          NaN
# ...               ...         ...      ...  ...              ...          ...
# 8923              NaN         NaN  unpaved  ...              NaN          NaN
# 8924              NaN         NaN      NaN  ...              NaN          NaN
# 8925              NaN         NaN      NaN  ...              NaN          NaN
# 8926              NaN         NaN      NaN  ...              NaN          NaN
# 8927              NaN         NaN      NaN  ...              NaN          NaN
#
#      old_name:ru parking:lane:right:condition abandoned turn:lanes:forward  \
# 0            NaN                          NaN       NaN                NaN
# 1            NaN                          NaN       NaN                NaN
# 2            NaN                          NaN       NaN                NaN
# 3            NaN                          NaN       NaN                NaN
# 4            NaN                          NaN       NaN                NaN
# ...          ...                          ...       ...                ...
# 8923         NaN                          NaN       NaN                NaN
# 8924         NaN                          NaN       NaN                NaN
# 8925         NaN                          NaN       NaN                NaN
# 8926         NaN                          NaN       NaN                NaN
# 8927         NaN                          NaN       NaN                NaN
#
#      was:oneway:bicycle was:oneway:psv motorcar turn:lanes:backward
# 0                   NaN            NaN      NaN                 NaN
# 1                   NaN            NaN      NaN                 NaN
# 2                   NaN            NaN      NaN                 NaN
# 3                   NaN            NaN      NaN                 NaN
# 4                   NaN            NaN      NaN                 NaN
# ...                 ...            ...      ...                 ...
# 8923                NaN            NaN      NaN                 NaN
# 8924                NaN            NaN      NaN                 NaN
# 8925                NaN            NaN      NaN                 NaN
# 8926                NaN            NaN      NaN                 NaN
# 8927                NaN            NaN      NaN                 NaN
#
# [8928 rows x 80 columns]

# %%
tags.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 8928 entries, 0 to 8927
# Data columns (total 80 columns):
#  #   Column                        Non-Null Count  Dtype
# ---  ------                        --------------  -----
#  0   foot                          959 non-null    object
#  1   hgv                           30 non-null     object
#  2   highway                       8928 non-null   object
#  3   lanes                         1386 non-null   object
#  4   lit                           1462 non-null   object
#  5   maxspeed                      1448 non-null   object
#  6   name                          1288 non-null   object
#  7   name:en                       539 non-null    object
#  8   postal_code                   152 non-null    object
#  9   surface                       3772 non-null   object
#  10  addr:postcode                 61 non-null     object
#  11  wikidata                      322 non-null    object
#  12  wikipedia                     325 non-null    object
#  13  oneway                        1287 non-null   object
#  14  trolley_wire                  271 non-null    object
#  15  turn:lanes                    120 non-null    object
#  16  noname                        9 non-null      object
#  17  smoothness                    292 non-null    object
#  18  name:ru                       494 non-null    object
#  19  bridge                        65 non-null     object
#  20  incline                       21 non-null     object
#  21  layer                         84 non-null     object
#  22  sidewalk                      24 non-null     object
#  23  parking                       1 non-null      object
#  24  bridge:movable                2 non-null      object
#  25  name:de                       14 non-null     object
#  26  side_road                     44 non-null     object
#  27  addr:suburb                   31 non-null     object
#  28  maxheight                     38 non-null     object
#  29  ref                           23 non-null     object
#  30  description                   1 non-null      object
#  31  comment                       11 non-null     object
#  32  int_ref                       11 non-null     object
#  33  name:fi                       9 non-null      object
#  34  official_name                 11 non-null     object
#  35  short_name                    9 non-null      object
#  36  source:maxspeed               16 non-null     object
#  37  living_street                 2064 non-null   object
#  38  junction                      11 non-null     object
#  39  alt_name                      3 non-null      object
#  40  length                        2 non-null      object
#  41  oneway:note                   3 non-null      object
#  42  maxweight:hgv                 3 non-null      object
#  43  vehicle                       94 non-null     object
#  44  service                       600 non-null    object
#  45  access                        930 non-null    object
#  46  old_name                      22 non-null     object
#  47  covered                       232 non-null    object
#  48  tunnel                        132 non-null    object
#  49  fixme                         18 non-null     object
#  50  junction:roundabout           8 non-null      object
#  51  cycleway:right                2 non-null      object
#  52  lanes:psv                     2 non-null      object
#  53  psv:lanes                     2 non-null      object
#  54  loc_name                      4 non-null      object
#  55  maxweight                     4 non-null      object
#  56  source                        175 non-null    object
#  57  psv                           13 non-null     object
#  58  passing_places                1 non-null      object
#  59  lanes:backward                4 non-null      object
#  60  lanes:forward                 4 non-null      object
#  61  placement                     3 non-null      object
#  62  motor_vehicle                 6 non-null      object
#  63  side                          1 non-null      object
#  64  traffic_sign:backward         1 non-null      object
#  65  parking:lane:right            4 non-null      object
#  66  check_date                    3 non-null      object
#  67  note                          8 non-null      object
#  68  parking:left                  1 non-null      object
#  69  maxspeed:backward             2 non-null      object
#  70  maxspeed:forward              2 non-null      object
#  71  construction                  5 non-null      object
#  72  old_name:ru                   1 non-null      object
#  73  parking:lane:right:condition  1 non-null      object
#  74  abandoned                     1 non-null      object
#  75  turn:lanes:forward            1 non-null      object
#  76  was:oneway:bicycle            2 non-null      object
#  77  was:oneway:psv                2 non-null      object
#  78  motorcar                      1 non-null      object
#  79  turn:lanes:backward           1 non-null      object
# dtypes: object(80)
# memory usage: 5.4+ MB

# %%
#Из всех тегов оставим только тег "name".
extract_tags = [
    "name",
]
# И прицепим их к улицам с помощью метода join. По умолчанию сопоставление происходит по столбцу с индексами.
gdf_streets = gdf_streets.join(tags[extract_tags])
gdf_streets
# Out:
#      type         id                                               tags  \
# 0     way    4454554  {'foot': 'no', 'hgv': 'no', 'highway': 'tertia...
# 1     way    4455612  {'addr:postcode': '193318', 'highway': 'tertia...
# 2     way    4456145  {'foot': 'no', 'highway': 'primary', 'lanes': ...
# 3     way    4456665  {'foot': 'no', 'highway': 'secondary', 'lanes'...
# 4     way    4456737  {'foot': 'no', 'highway': 'primary', 'lanes': ...
# ...   ...        ...                                                ...
# 8923  way  982174776       {'highway': 'service', 'surface': 'unpaved'}
# 8924  way  983845877  {'highway': 'service', 'service': 'parking_ais...
# 8925  way  983845878  {'highway': 'service', 'service': 'parking_ais...
# 8926  way  983845879  {'highway': 'service', 'service': 'parking_ais...
# 8927  way  983845880  {'highway': 'service', 'service': 'parking_ais...
#
#                                                geometry                 name
# 0     LINESTRING (3391641.514 8369024.600, 3391686.0...        улица Чернова
# 1     LINESTRING (3388065.876 8383198.675, 3388058.2...        Зольная улица
# 2     LINESTRING (3391979.892 8382039.064, 3391986.1...  Российский проспект
# 3     LINESTRING (3381745.367 8378798.756, 3381756.9...  Глухоозёрское шоссе
# 4     LINESTRING (3391760.525 8382110.538, 3391738.0...                  NaN
# ...                                                 ...                  ...
# 8923  LINESTRING (3387171.491 8370639.425, 3387147.9...                  NaN
# 8924  LINESTRING (3390005.551 8377847.117, 3389996.3...                  NaN
# 8925  LINESTRING (3389872.625 8377858.460, 3389955.5...                  NaN
# 8926  LINESTRING (3389876.755 8377827.961, 3389973.3...                  NaN
# 8927  LINESTRING (3389880.050 8377807.561, 3389985.5...                  NaN
#
# [8928 rows x 5 columns]

# %%
gdf_streets.dropna(
    how="all",  # удалить если отсутствуют значения во всех указанных столбцах
    subset=["name"],  # столбцы, в которых надо искать пропуски
    inplace=True
)
gdf_streets
# Out:
#      type         id                                               tags  \
# 0     way    4454554  {'foot': 'no', 'hgv': 'no', 'highway': 'tertia...
# 1     way    4455612  {'addr:postcode': '193318', 'highway': 'tertia...
# 2     way    4456145  {'foot': 'no', 'highway': 'primary', 'lanes': ...
# 3     way    4456665  {'foot': 'no', 'highway': 'secondary', 'lanes'...
# 5     way    4457777  {'highway': 'secondary', 'lanes': '3', 'lit': ...
# ...   ...        ...                                                ...
# 8870  way  977049605  {'highway': 'residential', 'lanes': '2', 'lit'...
# 8871  way  977049606  {'foot': 'no', 'highway': 'tertiary', 'lanes':...
# 8872  way  977049607  {'foot': 'no', 'highway': 'tertiary', 'lanes':...
# 8873  way  977049608  {'foot': 'no', 'highway': 'secondary', 'lanes'...
# 8874  way  977103620  {'highway': 'secondary', 'lanes': '4', 'lit': ...
#
#                                                geometry  \
# 0     LINESTRING (3391641.514 8369024.600, 3391686.0...
# 1     LINESTRING (3388065.876 8383198.675, 3388058.2...
# 2     LINESTRING (3391979.892 8382039.064, 3391986.1...
# 3     LINESTRING (3381745.367 8378798.756, 3381756.9...
# 5     LINESTRING (3390430.324 8381152.697, 3390472.5...
# ...                                                 ...
# 8870  LINESTRING (3385580.101 8377041.069, 3385599.5...
# 8871  LINESTRING (3386196.365 8377309.305, 3386206.7...
# 8872  LINESTRING (3386206.774 8377271.283, 3386231.7...
# 8873  LINESTRING (3394758.638 8381436.851, 3394767.8...
# 8874  LINESTRING (3391613.595 8381761.594, 3391524.1...
#
#                              name
# 0                   улица Чернова
# 1                   Зольная улица
# 2             Российский проспект
# 3             Глухоозёрское шоссе
# 5                 улица Коллонтай
# ...                           ...
# 8870               улица Пинегина
# 8871              улица Бабушкина
# 8872  Большой Смоленский проспект
# 8873        проспект Солидарности
# 8874              улица Коллонтай
#
# [1288 rows x 5 columns]

# %%
# Проверяем наличие дубликатов по полям "id", "geometry", "name"
tag_duble = [
    "id", 
    "geometry", 
    "name"
]
gdf_streets.duplicated(subset=tag_duble).value_counts()
# Out:
# False    1288
# dtype: int64

# %%
# Проверка, являются ли названия улиц уникальными.
gdf_streets["name"].is_unique
# Out:
# False

# %%
# Метод dissolve сгруппирует геометрии по столбцу "name" и объединит геометрии в одну
gdf_streets = gdf_streets.dissolve(by="name")
gdf_streets
# Out:
#                                                                     geometry  \
# name
# 1-й Рабфаковский переулок  LINESTRING (3391743.672 8368417.242, 3391766.1...
# 1-я дорога                 LINESTRING (3393246.184 8372403.217, 3393268.7...
# 11-я линия                 LINESTRING (3391094.356 8367013.072, 3391152.4...
# 13-я линия                 LINESTRING (3391016.210 8366855.634, 3391125.3...
# 2-й Рабфаковский переулок  LINESTRING (3392568.994 8367091.715, 3392561.7...
# ...                                                                      ...
# улица Чернова              MULTILINESTRING ((3391641.514 8369024.600, 339...
# улица Чудновского          MULTILINESTRING ((3392437.637 8382877.735, 339...
# улица Шелгунова            MULTILINESTRING ((3388527.362 8369046.328, 338...
# улица Шотмана              LINESTRING (3393696.427 8378027.677, 3393683.0...
# улица Юннатов              MULTILINESTRING ((3394541.498 8362686.152, 339...
#
#                           type         id  \
# name
# 1-й Рабфаковский переулок  way  132916332
# 1-я дорога                 way   59291558
# 11-я линия                 way  774757869
# 13-я линия                 way  774757865
# 2-й Рабфаковский переулок  way  173534236
# ...                        ...        ...
# улица Чернова              way    4454554
# улица Чудновского          way    8146822
# улица Шелгунова            way   31369845
# улица Шотмана              way   33996096
# улица Юннатов              way  101794902
#
#                                                                         tags
# name
# 1-й Рабфаковский переулок  {'highway': 'residential', 'lanes': '1', 'lit'...
# 1-я дорога                      {'highway': 'service', 'name': '1-я дорога'}
# 11-я линия                 {'access': 'private', 'highway': 'service', 'n...
# 13-я линия                 {'access': 'private', 'highway': 'service', 'n...
# 2-й Рабфаковский переулок  {'highway': 'residential', 'lanes': '1', 'lit'...
# ...                                                                      ...
# улица Чернова              {'foot': 'no', 'hgv': 'no', 'highway': 'tertia...
# улица Чудновского          {'foot': 'no', 'highway': 'residential', 'lane...
# улица Шелгунова            {'foot': 'no', 'highway': 'residential', 'lane...
# улица Шотмана              {'foot': 'no', 'highway': 'residential', 'lane...
# улица Юннатов              {'highway': 'tertiary', 'lanes': '2', 'lit': '...
#
# [177 rows x 4 columns]

# %%
# Столбец "name" переиминуем в "Название улицы"
gdf_streets.index.rename("Название улицы", inplace=True)
gdf_streets.head()
# Out:
#                                                                     geometry  \
# Название улицы
# 1-й Рабфаковский переулок  LINESTRING (3391743.672 8368417.242, 3391766.1...
# 1-я дорога                 LINESTRING (3393246.184 8372403.217, 3393268.7...
# 11-я линия                 LINESTRING (3391094.356 8367013.072, 3391152.4...
# 13-я линия                 LINESTRING (3391016.210 8366855.634, 3391125.3...
# 2-й Рабфаковский переулок  LINESTRING (3392568.994 8367091.715, 3392561.7...
#
#                           type         id  \
# Название улицы
# 1-й Рабфаковский переулок  way  132916332
# 1-я дорога                 way   59291558
# 11-я линия                 way  774757869
# 13-я линия                 way  774757865
# 2-й Рабфаковский переулок  way  173534236
#
#                                                                         tags
# Название улицы
# 1-й Рабфаковский переулок  {'highway': 'residential', 'lanes': '1', 'lit'...
# 1-я дорога                      {'highway': 'service', 'name': '1-я дорога'}
# 11-я линия                 {'access': 'private', 'highway': 'service', 'n...
# 13-я линия                 {'access': 'private', 'highway': 'service', 'n...
# 2-й Рабфаковский переулок  {'highway': 'residential', 'lanes': '1', 'lit'...

# %%
# Удаляем столбцы "id", "type" и "tags"
drop_columns = [
    "id", 
    "type",
    "tags"
]
gdf_streets.drop(columns=drop_columns, inplace=True)
gdf_streets.head()
# Out:
#                                                                     geometry
# Название улицы
# 1-й Рабфаковский переулок  LINESTRING (3391743.672 8368417.242, 3391766.1...
# 1-я дорога                 LINESTRING (3393246.184 8372403.217, 3393268.7...
# 11-я линия                 LINESTRING (3391094.356 8367013.072, 3391152.4...
# 13-я линия                 LINESTRING (3391016.210 8366855.634, 3391125.3...
# 2-й Рабфаковский переулок  LINESTRING (3392568.994 8367091.715, 3392561.7...

# %%
gdf_streets.explore(tiles=TILES)
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;head&gt;
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#
#         &lt;script&gt;
#             L_NO_TOUCH = false;
#             L_DISABLE_3D = false;
#         &lt;/script&gt;
#
#     &lt;style&gt;html, body {width: 100%;height: 100%;margin: 0;padding: 0;}&lt;/style&gt;
#     &lt;style&gt;#map {position:absolute;top:0;bottom:0;right:0;left:0;}&lt;/style&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.6.0/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-1.12.4.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://maxcdn.bootstrapcdn.com/bootstrap/3.2.0/js/bootstrap.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.6.0/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://maxcdn.bootstrapcdn.com/bootstrap/3.2.0/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://maxcdn.bootstrapcdn.com/bootstrap/3.2.0/css/bootstrap-theme.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://maxcdn.bootstrapcdn.com/font-awesome/4.6.3/css/font-awesome.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_7e939d0a9c34281363a2f971e6c934f6 {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#             &lt;/style&gt;
#
#
#                     &lt;style&gt;
#                         .foliumtooltip {
#
#                         }
#                        .foliumtooltip table{
#                             margin: auto;
#                         }
#                         .foliumtooltip tr{
#                             text-align: left;
#                         }
#                         .foliumtooltip th{
#                             padding: 2px; padding-right: 8px;
#                         }
#                     &lt;/style&gt;
#
# &lt;/head&gt;
# &lt;body&gt;
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_7e939d0a9c34281363a2f971e6c934f6&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#             var map_7e939d0a9c34281363a2f971e6c934f6 = L.map(
#                 &quot;map_7e939d0a9c34281363a2f971e6c934f6&quot;,
#                 {
#                     center: [59.87088815, 30.4809201],
#                     crs: L.CRS.EPSG3857,
#                     zoom: 10,
#                     zoomControl: true,
#                     preferCanvas: false,
#                 }
#             );
#             L.control.scale().addTo(map_7e939d0a9c34281363a2f971e6c934f6);
#
#
#
#
#
#             var tile_layer_d27e9b58d467c81016a4f59ad82f1cda = L.tileLayer(
#                 &quot;https://cartodb-basemaps-{s}.global.ssl.fastly.net/light_all/{z}/{x}/{y}.png&quot;,
#                 {&quot;attribution&quot;: &quot;\u0026copy; \u003ca href=\&quot;http://www.openstreetmap.org/copyright\&quot;\u003eOpenStreetMap\u003c/a\u003e contributors \u0026copy; \u003ca href=\&quot;http://cartodb.com/attributions\&quot;\u003eCartoDB\u003c/a\u003e, CartoDB \u003ca href =\&quot;http://cartodb.com/attributions\&quot;\u003eattributions\u003c/a\u003e&quot;, &quot;detectRetina&quot;: false, &quot;maxNativeZoom&quot;: 18, &quot;maxZoom&quot;: 18, &quot;minZoom&quot;: 0, &quot;noWrap&quot;: false, &quot;opacity&quot;: 1, &quot;subdomains&quot;: &quot;abc&quot;, &quot;tms&quot;: false}
#             ).addTo(map_7e939d0a9c34281363a2f971e6c934f6);
#
#
#             map_7e939d0a9c34281363a2f971e6c934f6.fitBounds(
#                 [[59.80486949999999, 30.3624536], [59.9369068, 30.5993866]],
#                 {}
#             );
#
#
#         function geo_json_0d55d113079a6ca00a39068b5e598e15_styler(feature) {
#             switch(feature.id) {
#                 default:
#                     return {&quot;fillOpacity&quot;: 0.5, &quot;weight&quot;: 2};
#             }
#         }
#         function geo_json_0d55d113079a6ca00a39068b5e598e15_highlighter(feature) {
#             switch(feature.id) {
#                 default:
#                     return {&quot;fillOpacity&quot;: 0.75};
#             }
#         }
#         function geo_json_0d55d113079a6ca00a39068b5e598e15_pointToLayer(feature, latlng) {
#             var opts = {&quot;bubblingMouseEvents&quot;: true, &quot;color&quot;: &quot;#3388ff&quot;, &quot;dashArray&quot;: null, &quot;dashOffset&quot;: null, &quot;fill&quot;: true, &quot;fillColor&quot;: &quot;#3388ff&quot;, &quot;fillOpacity&quot;: 0.2, &quot;fillRule&quot;: &quot;evenodd&quot;, &quot;lineCap&quot;: &quot;round&quot;, &quot;lineJoin&quot;: &quot;round&quot;, &quot;opacity&quot;: 1.0, &quot;radius&quot;: 2, &quot;stroke&quot;: true, &quot;weight&quot;: 3};
#
#             let style = geo_json_0d55d113079a6ca00a39068b5e598e15_styler(feature)
#             Object.assign(opts, style)
#
#             return new L.CircleMarker(latlng, opts)
#         }
#
#         function geo_json_0d55d113079a6ca00a39068b5e598e15_onEachFeature(feature, layer) {
#             layer.on({
#                 mouseout: function(e) {
#                     if(typeof e.target.setStyle === &quot;function&quot;){
#                         geo_json_0d55d113079a6ca00a39068b5e598e15.resetStyle(e.target);
#                     }
#                 },
#                 mouseover: function(e) {
#                     if(typeof e.target.setStyle === &quot;function&quot;){
#                         const highlightStyle = geo_json_0d55d113079a6ca00a39068b5e598e15_highlighter(e.target.feature)
#                         e.target.setStyle(highlightStyle);
#                     }
#                 },
#             });
#         };
#         var geo_json_0d55d113079a6ca00a39068b5e598e15 = L.geoJson(null, {
#                 onEachFeature: geo_json_0d55d113079a6ca00a39068b5e598e15_onEachFeature,
#
#                 style: geo_json_0d55d113079a6ca00a39068b5e598e15_styler,
#                 pointToLayer: geo_json_0d55d113079a6ca00a39068b5e598e15_pointToLayer
#         });
#
#         function geo_json_0d55d113079a6ca00a39068b5e598e15_add (data) {
#             geo_json_0d55d113079a6ca00a39068b5e598e15
#                 .addData(data)
#                 .addTo(map_7e939d0a9c34281363a2f971e6c934f6);
#         }
#             geo_json_0d55d113079a6ca00a39068b5e598e15_add({&quot;bbox&quot;: [30.3624536, 59.80486949999999, 30.5993866, 59.9369068], &quot;features&quot;: [{&quot;bbox&quot;: [30.468551799999997, 59.85781979999999, 30.476788500000005, 59.85902149999999], &quot;geometry&quot;: {&quot;coordinates&quot;: [[30.468551799999997, 59.85902149999999], [30.4687539, 59.85897409999999], [30.469969299999992, 59.8586894], [30.4700995, 59.8586617], [30.470420500000003, 59.85859339999999], [30.470628, 59.85829139999999], [30.470729200000005, 59.8582342], [30.4708614, 59.8582101], [30.471144300000002, 59.858162], [30.471430699999996, 59.8581065], [30.471827400000002, 59.8580342], [30.471919500000002, 59.8580169], [30.472223400000004,

# %% [markdown]
# ## Объекты культурного наследия

# %% [markdown]
# ### Загрузка объектов культурного наследия

# %%
#Загружаем объекты культупного наследия в соотвествии с нашей маской (Невский район)
gdf_kgiop_objects = gpd.read_file(KGIOP_FILE_URL, mask=territory)
gdf_kgiop_objects
# Out:
#        id                                      ensemble_name  \
# 0    4072                     Палевский жилмассив (19 домов)
# 1    4051                                                  —
# 2    3974                                                  —
# 3    3975                                                  —
# 4    4008                                                  —
# ..    ...                                                ...
# 244  9618  Рабочий городок при ГРЭС "Красный Октябрь" (ТЭ...
# 245  9619  Рабочий городок при ГРЭС "Красный Октябрь" (ТЭ...
# 246  9620  Рабочий городок при ГРЭС "Красный Октябрь" (ТЭ...
# 247  9621  Рабочий городок при ГРЭС "Красный Октябрь" (ТЭ...
# 248  9650                                                  —
#
#                                            object_name occurrence_time  \
# 0                                            Жилой дом       1925-1928
# 1                     Здание школы (с садом и оградой)       1932-1933
# 2                               Октябрьская набережная       1932-1936
# 3                      Терраса у завода им. Ломоносова            1926
# 4                                Шлиссельбургский мост       1928-1929
# ..                                                 ...             ...
# 244                                          Жилой дом       1926-1928
# 245                                          Жилой дом       1926-1928
# 246                                          Жилой дом       1926-1928
# 247                                          Жилой дом       1926-1928
# 248  Участок сохранившегося культурного слоя, вмеща...               —
#
#                                        object_location  \
# 0                  Обуховской Обороны пр., 95, корп. 6
# 1                   Большой Смоленский пр., 36, лит. А
# 2    На правом берегу р. Невы, от устья р. Утки до ...
# 3                 На р. Неве по пр. Обуховской Обороны
# 4       Через Обводный канал по Обуховской обороны пр.
# ..                                                 ...
# 244             Октябрьская наб., 94, корпус 3, лит. В
# 245             Октябрьская наб., 96, корпус 1, лит. М
# 246             Октябрьская наб., 96, корпус 2, лит. А
# 247             Октябрьская наб., 96, корпус 3, лит. А
# 248                               сад 30-летия Октября
#
#                                    historical_category  \
# 0               выявленный объект культурного наследия
# 1               выявленный объект культурного наследия
# 2    объект культурного наследия регионального знач...
# 3    объект культурного наследия регионального знач...
# 4    объект культурного наследия регионального знач...
# ..                                                 ...
# 244  объект культурного наследия регионального знач...
# 245  объект культурного наследия регионального знач...
# 246  объект культурного наследия регионального знач...
# 247  объект культурного наследия регионального знач...
# 248             выявленный объект культурного наследия
#
#                                          normative_act object_type  \
# 0         Приказ председателя КГИОП № 15 от 20.02.2001    Памятник
# 1         Приказ председателя КГИОП № 15 от 20.02.2001    Ансамбль
# 2    Распоряжение мэра Санкт-Петербурга № 108-р от ...    Ансамбль
# 3    Распоряжение мэра Санкт-Петербурга № 108-р от ...    Памятник
# 4    Распоряжение мэра Санкт-Петербурга № 108-р от ...    Памятник
# ..                                                 ...         ...
# 244           Распоряжение КГИОП от 14.08.2019 № 491-р    Памятник
# 245           Распоряжение КГИОП от 14.08.2019 № 491-р    Памятник
# 246           Распоряжение КГИОП от 14.08.2019 № 491-р    Памятник
# 247           Распоряжение КГИОП от 14.08.2019 № 491-р    Памятник
# 248           Распоряжение КГИОП № 114-р от 08.04.2020    Ансамбль
#
#                             geometry
# 0    POINT (3387453.441 8376910.050)
# 1    POINT (3385184.415 8376455.066)
# 2    POINT (3388501.848 8377901.347)
# 3    POINT (3389224.756 8373469.957)
# 4    POINT (3383805.278 8381795.019)
# ..                               ...
# 244  POINT (3392198.323 8371250.714)
# 245  POINT (3392241.960 8371116.095)
# 246  POINT (3392244.854 8371170.652)
# 247  POINT (3392259.882 8371238.738)
# 248  POINT (3384491.006 8380373.955)
#
# [249 rows x 9 columns]

# %%
# Оставляем только столбцы object_name, object_location, object_type
gdf_kgiop_objects.drop(gdf_kgiop_objects.columns.difference(['object_name','object_location','object_type', 'geometry']), 1, inplace=True)
# Проверяем
gdf_kgiop_objects
# Out:
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:2: FutureWarning: In a future version of pandas all arguments of DataFrame.drop except for the argument 'labels' will be keyword-only
#                                            object_name  \
# 0                                            Жилой дом
# 1                     Здание школы (с садом и оградой)
# 2                               Октябрьская набережная
# 3                      Терраса у завода им. Ломоносова
# 4                                Шлиссельбургский мост
# ..                                                 ...
# 244                                          Жилой дом
# 245                                          Жилой дом
# 246                                          Жилой дом
# 247                                          Жилой дом
# 248  Участок сохранившегося культурного слоя, вмеща...
#
#                                        object_location object_type  \
# 0                  Обуховской Обороны пр., 95, корп. 6    Памятник
# 1                   Большой Смоленский пр., 36, лит. А    Ансамбль
# 2    На правом берегу р. Невы, от устья р. Утки до ...    Ансамбль
# 3                 На р. Неве по пр. Обуховской Обороны    Памятник
# 4       Через Обводный канал по Обуховской обороны пр.    Памятник
# ..                                                 ...         ...
# 244             Октябрьская наб., 94, корпус 3, лит. В    Памятник
# 245             Октябрьская наб., 96, корпус 1, лит. М    Памятник
# 246             Октябрьская наб., 96, корпус 2, лит. А    Памятник
# 247             Октябрьская наб., 96, корпус 3, лит. А    Памятник
# 248                               сад 30-летия Октября    Ансамбль
#
#                             geometry
# 0    POINT (3387453.441 8376910.050)
# 1    POINT (3385184.415 8376455.066)
# 2    POINT (3388501.848 8377901.347)
# 3    POINT (3389224.756 8373469.957)
# 4    POINT (3383805.278 8381795.019)
# ..                               ...
# 244  POINT (3392198.323 8371250.714)
# 245  POINT (3392241.960 8371116.095)
# 246  POINT (3392244.854 8371170.652)
# 247  POINT (3392259.882 8371238.738)
# 248  POINT (3384491.006 8380373.955)
#
# [249 rows x 4 columns]

# %%
# Переименовываем столбцы object_name, object_location, object_type в русские названия
tag_rename = {
    'object_name':'Наименование', 
    'object_location':'Локация', 
    'object_type':'Тип'
}
gdf_kgiop_objects.rename(columns=tag_rename, inplace=True)
# Проверяем
gdf_kgiop_objects
# Out:
#                                           Наименование  \
# 0                                            Жилой дом
# 1                     Здание школы (с садом и оградой)
# 2                               Октябрьская набережная
# 3                      Терраса у завода им. Ломоносова
# 4                                Шлиссельбургский мост
# ..                                                 ...
# 244                                          Жилой дом
# 245                                          Жилой дом
# 246                                          Жилой дом
# 247                                          Жилой дом
# 248  Участок сохранившегося культурного слоя, вмеща...
#
#                                                Локация       Тип  \
# 0                  Обуховской Обороны пр., 95, корп. 6  Памятник
# 1                   Большой Смоленский пр., 36, лит. А  Ансамбль
# 2    На правом берегу р. Невы, от устья р. Утки до ...  Ансамбль
# 3                 На р. Неве по пр. Обуховской Обороны  Памятник
# 4       Через Обводный канал по Обуховской обороны пр.  Памятник
# ..                                                 ...       ...
# 244             Октябрьская наб., 94, корпус 3, лит. В  Памятник
# 245             Октябрьская наб., 96, корпус 1, лит. М  Памятник
# 246             Октябрьская наб., 96, корпус 2, лит. А  Памятник
# 247             Октябрьская наб., 96, корпус 3, лит. А  Памятник
# 248                               сад 30-летия Октября  Ансамбль
#
#                             geometry
# 0    POINT (3387453.441 8376910.050)
# 1    POINT (3385184.415 8376455.066)
# 2    POINT (3388501.848 8377901.347)
# 3    POINT (3389224.756 8373469.957)
# 4    POINT (3383805.278 8381795.019)
# ..                               ...
# 244  POINT (3392198.323 8371250.714)
# 245  POINT (3392241.960 8371116.095)
# 246  POINT (3392244.854 8371170.652)
# 247  POINT (3392259.882 8371238.738)
# 248  POINT (3384491.006 8380373.955)
#
# [249 rows x 4 columns]

# %%
gdf_kgiop_objects.explore(tiles=TILES)
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;head&gt;
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#
#         &lt;script&gt;
#             L_NO_TOUCH = false;
#             L_DISABLE_3D = false;
#         &lt;/script&gt;
#
#     &lt;style&gt;html, body {width: 100%;height: 100%;margin: 0;padding: 0;}&lt;/style&gt;
#     &lt;style&gt;#map {position:absolute;top:0;bottom:0;right:0;left:0;}&lt;/style&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.6.0/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-1.12.4.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://maxcdn.bootstrapcdn.com/bootstrap/3.2.0/js/bootstrap.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.6.0/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://maxcdn.bootstrapcdn.com/bootstrap/3.2.0/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://maxcdn.bootstrapcdn.com/bootstrap/3.2.0/css/bootstrap-theme.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://maxcdn.bootstrapcdn.com/font-awesome/4.6.3/css/font-awesome.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_aad14a39b6b4e021b16222d003539c3a {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#             &lt;/style&gt;
#
#
#                     &lt;style&gt;
#                         .foliumtooltip {
#
#                         }
#                        .foliumtooltip table{
#                             margin: auto;
#                         }
#                         .foliumtooltip tr{
#                             text-align: left;
#                         }
#                         .foliumtooltip th{
#                             padding: 2px; padding-right: 8px;
#                         }
#                     &lt;/style&gt;
#
# &lt;/head&gt;
# &lt;body&gt;
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_aad14a39b6b4e021b16222d003539c3a&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#             var map_aad14a39b6b4e021b16222d003539c3a = L.map(
#                 &quot;map_aad14a39b6b4e021b16222d003539c3a&quot;,
#                 {
#                     center: [59.87683700000001, 30.453089499999997],
#                     crs: L.CRS.EPSG3857,
#                     zoom: 10,
#                     zoomControl: true,
#                     preferCanvas: false,
#                 }
#             );
#             L.control.scale().addTo(map_aad14a39b6b4e021b16222d003539c3a);
#
#
#
#
#
#             var tile_layer_17b18c51e123bbcc5052097a8f565b28 = L.tileLayer(
#                 &quot;https://cartodb-basemaps-{s}.global.ssl.fastly.net/light_all/{z}/{x}/{y}.png&quot;,
#                 {&quot;attribution&quot;: &quot;\u0026copy; \u003ca href=\&quot;http://www.openstreetmap.org/copyright\&quot;\u003eOpenStreetMap\u003c/a\u003e contributors \u0026copy; \u003ca href=\&quot;http://cartodb.com/attributions\&quot;\u003eCartoDB\u003c/a\u003e, CartoDB \u003ca href =\&quot;http://cartodb.com/attributions\&quot;\u003eattributions\u003c/a\u003e&quot;, &quot;detectRetina&quot;: false, &quot;maxNativeZoom&quot;: 18, &quot;maxZoom&quot;: 18, &quot;minZoom&quot;: 0, &quot;noWrap&quot;: false, &quot;opacity&quot;: 1, &quot;subdomains&quot;: &quot;abc&quot;, &quot;tms&quot;: false}
#             ).addTo(map_aad14a39b6b4e021b16222d003539c3a);
#
#
#             map_aad14a39b6b4e021b16222d003539c3a.fitBounds(
#                 [[59.834364, 30.384558999999992], [59.91931000000001, 30.52162]],
#                 {}
#             );
#
#
#         function geo_json_db53844130d43e0aea85621d561fb9cd_styler(feature) {
#             switch(feature.id) {
#                 default:
#                     return {&quot;fillOpacity&quot;: 0.5, &quot;weight&quot;: 2};
#             }
#         }
#         function geo_json_db53844130d43e0aea85621d561fb9cd_highlighter(feature) {
#             switch(feature.id) {
#                 default:
#                     return {&quot;fillOpacity&quot;: 0.75};
#             }
#         }
#         function geo_json_db53844130d43e0aea85621d561fb9cd_pointToLayer(feature, latlng) {
#             var opts = {&quot;bubblingMouseEvents&quot;: true, &quot;color&quot;: &quot;#3388ff&quot;, &quot;dashArray&quot;: null, &quot;dashOffset&quot;: null, &quot;fill&quot;: true, &quot;fillColor&quot;: &quot;#3388ff&quot;, &quot;fillOpacity&quot;: 0.2, &quot;fillRule&quot;: &quot;evenodd&quot;, &quot;lineCap&quot;: &quot;round&quot;, &quot;lineJoin&quot;: &quot;round&quot;, &quot;opacity&quot;: 1.0, &quot;radius&quot;: 2, &quot;stroke&quot;: true, &quot;weight&quot;: 3};
#
#             let style = geo_json_db53844130d43e0aea85621d561fb9cd_styler(feature)
#             Object.assign(opts, style)
#
#             return new L.CircleMarker(latlng, opts)
#         }
#
#         function geo_json_db53844130d43e0aea85621d561fb9cd_onEachFeature(feature, layer) {
#             layer.on({
#                 mouseout: function(e) {
#                     if(typeof e.target.setStyle === &quot;function&quot;){
#                         geo_json_db53844130d43e0aea85621d561fb9cd.resetStyle(e.target);
#                     }
#                 },
#                 mouseover: function(e) {
#                     if(typeof e.target.setStyle === &quot;function&quot;){
#                         const highlightStyle = geo_json_db53844130d43e0aea85621d561fb9cd_highlighter(e.target.feature)
#                         e.target.setStyle(highlightStyle);
#                     }
#                 },
#             });
#         };
#         var geo_json_db53844130d43e0aea85621d561fb9cd = L.geoJson(null, {
#                 onEachFeature: geo_json_db53844130d43e0aea85621d561fb9cd_onEachFeature,
#
#                 style: geo_json_db53844130d43e0aea85621d561fb9cd_styler,
#                 pointToLayer: geo_json_db53844130d43e0aea85621d561fb9cd_pointToLayer
#         });
#
#         function geo_json_db53844130d43e0aea85621d561fb9cd_add (data) {
#             geo_json_db53844130d43e0aea85621d561fb9cd
#                 .addData(data)
#                 .addTo(map_aad14a39b6b4e021b16222d003539c3a);
#         }
#             geo_json_db53844130d43e0aea85621d561fb9cd_add({&quot;bbox&quot;: [30.384558999999992, 59.834364, 30.52162, 59.91931000000001], &quot;features&quot;: [{&quot;bbox&quot;: [30.430011999999998, 59.89730800000001, 30.430011999999998, 59.89730800000001], &quot;geometry&quot;: {&quot;coordinates&quot;: [30.430011999999998, 59.89730800000001], &quot;type&quot;: &quot;Point&quot;}, &quot;id&quot;: &quot;0&quot;, &quot;properties&quot;: {&quot;\u041b\u043e\u043a\u0430\u0446\u0438\u044f&quot;: &quot;\u041e\u0431\u0443\u0445\u043e\u0432\u0441\u043a\u043e\u0439 \u041e\u0431\u043e\u0440\u043e\u043d\u044b \u043f\u0440., 95, \u043a\u043e\u0440\u043f. 6&quot;, &quot;\u041d\u0430\u0438\u043c\u0435\u043d\u

# %%
def get_contains_kgiop_objects(street) -> int:
    """ Функция для подсчета количества объектов культурного наследия попадающих в буффер улицы"""
    return sum(gdf_kgiop_objects["geometry"].within(street.buffer(STREET_BUFFER)))


gdf_streets["contains_kgiop_objects"] = gdf_streets["geometry"].apply(get_contains_kgiop_objects)
gdf_streets.nlargest(5, "contains_kgiop_objects")
# Out:
#                                                                       geometry  \
# Название улицы
# проспект Обуховской Обороны  MULTILINESTRING ((3389659.225 8372593.936, 338...
# Октябрьская набережная       MULTILINESTRING ((3390229.059 8372810.613, 339...
# Ивановская улица             MULTILINESTRING ((3387949.614 8371426.765, 338...
# улица Бабушкина              MULTILINESTRING ((3392909.164 8368574.958, 339...
# улица Ткачей                 MULTILINESTRING ((3388204.959 8376339.615, 338...
#
#                              contains_kgiop_objects
# Название улицы
# проспект Обуховской Обороны                      30
# Октябрьская набережная                           19
# Ивановская улица                                 10
# улица Бабушкина                                  10
# улица Ткачей                                     10

# %%
gdf_streets.explore("contains_kgiop_objects", tiles=TILES)
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;head&gt;
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#
#         &lt;script&gt;
#             L_NO_TOUCH = false;
#             L_DISABLE_3D = false;
#         &lt;/script&gt;
#
#     &lt;style&gt;html, body {width: 100%;height: 100%;margin: 0;padding: 0;}&lt;/style&gt;
#     &lt;style&gt;#map {position:absolute;top:0;bottom:0;right:0;left:0;}&lt;/style&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.6.0/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-1.12.4.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://maxcdn.bootstrapcdn.com/bootstrap/3.2.0/js/bootstrap.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.6.0/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://maxcdn.bootstrapcdn.com/bootstrap/3.2.0/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://maxcdn.bootstrapcdn.com/bootstrap/3.2.0/css/bootstrap-theme.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://maxcdn.bootstrapcdn.com/font-awesome/4.6.3/css/font-awesome.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_c789c2b937a4c2be8b84efa6f2468ff7 {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#             &lt;/style&gt;
#
#
#                     &lt;style&gt;
#                         .foliumtooltip {
#
#                         }
#                        .foliumtooltip table{
#                             margin: auto;
#                         }
#                         .foliumtooltip tr{
#                             text-align: left;
#                         }
#                         .foliumtooltip th{
#                             padding: 2px; padding-right: 8px;
#                         }
#                     &lt;/style&gt;
#
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/d3/3.5.5/d3.min.js&quot;&gt;&lt;/script&gt;
# &lt;/head&gt;
# &lt;body&gt;
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_c789c2b937a4c2be8b84efa6f2468ff7&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#             var map_c789c2b937a4c2be8b84efa6f2468ff7 = L.map(
#                 &quot;map_c789c2b937a4c2be8b84efa6f2468ff7&quot;,
#                 {
#                     center: [59.87088815, 30.4809201],
#                     crs: L.CRS.EPSG3857,
#                     zoom: 10,
#                     zoomControl: true,
#                     preferCanvas: false,
#                 }
#             );
#             L.control.scale().addTo(map_c789c2b937a4c2be8b84efa6f2468ff7);
#
#
#
#
#
#             var tile_layer_249aa0d0fcb579a364d4a40e5542fe12 = L.tileLayer(
#                 &quot;https://cartodb-basemaps-{s}.global.ssl.fastly.net/light_all/{z}/{x}/{y}.png&quot;,
#                 {&quot;attribution&quot;: &quot;\u0026copy; \u003ca href=\&quot;http://www.openstreetmap.org/copyright\&quot;\u003eOpenStreetMap\u003c/a\u003e contributors \u0026copy; \u003ca href=\&quot;http://cartodb.com/attributions\&quot;\u003eCartoDB\u003c/a\u003e, CartoDB \u003ca href =\&quot;http://cartodb.com/attributions\&quot;\u003eattributions\u003c/a\u003e&quot;, &quot;detectRetina&quot;: false, &quot;maxNativeZoom&quot;: 18, &quot;maxZoom&quot;: 18, &quot;minZoom&quot;: 0, &quot;noWrap&quot;: false, &quot;opacity&quot;: 1, &quot;subdomains&quot;: &quot;abc&quot;, &quot;tms&quot;: false}
#             ).addTo(map_c789c2b937a4c2be8b84efa6f2468ff7);
#
#
#             map_c789c2b937a4c2be8b84efa6f2468ff7.fitBounds(
#                 [[59.80486949999999, 30.3624536], [59.9369068, 30.5993866]],
#                 {}
#             );
#
#
#         function geo_json_4af6e6214c6187b7b97f137055ca0366_styler(feature) {
#             switch(feature.id) {
#                 case &quot;23&quot;: case &quot;147&quot;: case &quot;171&quot;:
#                     return {&quot;color&quot;: &quot;#482475&quot;, &quot;fillColor&quot;: &quot;#482475&quot;, &quot;fillOpacity&quot;: 0.5, &quot;weight&quot;: 2};
#                 case &quot;30&quot;: case &quot;31&quot;: case &quot;60&quot;: case &quot;66&quot;: case &quot;79&quot;: case &quot;89&quot;: case &quot;99&quot;: case &quot;112&quot;: case &quot;123&quot;: case &quot;142&quot;: case &quot;150&quot;: case &quot;156&quot;:
#                     return {&quot;color&quot;: &quot;#470d60&quot;, &quot;fillColor&quot;: &quot;#470d60&quot;, &quot;fillOpacity&quot;: 0.5, &quot;weight&quot;: 2};
#                 case &quot;36&quot;: case &quot;50&quot;: case &quot;59&quot;: case &quot;110&quot;: case &quot;122&quot;: case &quot;129&quot;:
#                     return {&quot;color&quot;: &quot;#481a6c&quot;, &quot;fillColor&quot;: &quot;#481a6c&quot;, &quot;fillOpacity&quot;: 0.5, &quot;weight&quot;: 2};
#                 case &quot;47&quot;: case &quot;139&quot;: case &quot;170&quot;:
#                     return {&quot;color&quot;: &quot;#31688e&quot;, &quot;fillColor&quot;: &quot;#31688e&quot;, &quot;fillOpacity&quot;: 0.5, &quot;weight&quot;: 2};
#                 case &quot;70&quot;:
#                     return {&quot;color&quot;: &quot;#2ab07f&quot;, &quot;fillColor&quot;: &quot;#2ab07f&quot;, &quot;fillOpacity&quot;: 0.5, &quot;weight&quot;: 2};
#                 case &quot;86&quot;: case &quot;128&quot;: case &quot;131&quot;:
#                     return {&quot;color&quot;: &quot;#443983&quot;, &quot;fillColor&quot;: &quot;#443983&quot;, &quot;fillOpacity&quot;: 0.5, &quot;weight&quot;: 2};
#                 case &quot;106&quot;: case &quot;124&quot;: case &quot;162&quot;:
#                     return {&quot;color&quot;: &quot;#472f7d&quot;, &quot;fillColor&quot;: &quot;#472f7d&quot;, &quot;fillOpacity&quot;: 0.5, &quot;weight&quot;: 2};
#                 case &quot;132&quot;:
#                     return {&quot;color&quot;: &quot;#fde725&quot;, &quot;fillColor&quot;: &quot;#fde725&quot;, &quot;fillOpacity&quot;: 0.5, &quot;weight&quot;: 2};
#                 default:
#                     return {&quot;color&quot;: &quot;#440154&quot;, &quot;fillColor&quot;: &quot;#440154&quot;, &quot;fillOpacity&quot;: 0.5, &quot;weight&quot;: 2};
#             }
#         }
#         function geo_json_4af6e6214c6187b7b97f137055ca0366_highlighter(feature) {
#             switch(feature.id) {
#                 default:
#                     return {&quot;fillOpacity&quot;: 0.75};
#             }
#         }
#         function geo_json_4af6e6214c6187b7b97f137055ca0366_pointToLayer(feature, latlng) {
#             var opts = {&quot;bubblingMouseEvents&quot;: true, &quot;color&quot;: &quot;#3388ff&quot;, &quot;dashArray&quot;: null, &quot;dashOffset&quot;: null, &quot;fill&quot;: true, &quot;fillColor&quot;: &quot;#3388ff&quot;, &quot;fillOpacity&quot;: 0.2, &quot;fillRule&quot;: &quot;evenodd&quot;, &quot;lineCap&quot;: &quot;round&quot;, &quot;lineJoin&quot;: &quo

# %%
# Некая статистика
gdf_streets["density"] = gdf_streets["contains_kgiop_objects"] / gdf_streets.length
gdf_streets.nlargest(5, "density")
# Out:
#                                                                 geometry  \
# Название улицы
# площадь Культуры       MULTILINESTRING ((3387118.792 8375902.398, 338...
# переулок Ногина        LINESTRING (3386979.899 8377292.902, 3386990.9...
# Шлиссельбургский мост  MULTILINESTRING ((3383839.965 8381783.026, 338...
# улица Ткачей           MULTILINESTRING ((3388204.959 8376339.615, 338...
# Стеклянная улица       LINESTRING (3384618.055 8380365.517, 3384640.6...
#
#                        contains_kgiop_objects   density
# Название улицы
# площадь Культуры                            5  0.011250
# переулок Ногина                             4  0.010771
# Шлиссельбургский мост                       1  0.007515
# улица Ткачей                               10  0.004358
# Стеклянная улица                            1  0.002366

# %%
# Переименовываем столбцы contains_kgiop_objects и density в русские названия
gdf_streets.rename(columns={'contains_kgiop_objects':'Кол-во КГИОП объектов', 'density':'плотность'}, inplace=True)
gdf_streets
# Out:
#                                                                     geometry  \
# Название улицы
# 1-й Рабфаковский переулок  LINESTRING (3391743.672 8368417.242, 3391766.1...
# 1-я дорога                 LINESTRING (3393246.184 8372403.217, 3393268.7...
# 11-я линия                 LINESTRING (3391094.356 8367013.072, 3391152.4...
# 13-я линия                 LINESTRING (3391016.210 8366855.634, 3391125.3...
# 2-й Рабфаковский переулок  LINESTRING (3392568.994 8367091.715, 3392561.7...
# ...                                                                      ...
# улица Чернова              MULTILINESTRING ((3391641.514 8369024.600, 339...
# улица Чудновского          MULTILINESTRING ((3392437.637 8382877.735, 339...
# улица Шелгунова            MULTILINESTRING ((3388527.362 8369046.328, 338...
# улица Шотмана              LINESTRING (3393696.427 8378027.677, 3393683.0...
# улица Юннатов              MULTILINESTRING ((3394541.498 8362686.152, 339...
#
#                            Кол-во КГИОП объектов  плотность
# Название улицы
# 1-й Рабфаковский переулок                      0        0.0
# 1-я дорога                                     0        0.0
# 11-я линия                                     0        0.0
# 13-я линия                                     0        0.0
# 2-й Рабфаковский переулок                      0        0.0
# ...                                          ...        ...
# улица Чернова                                  0        0.0
# улица Чудновского                              0        0.0
# улица Шелгунова                                0        0.0
# улица Шотмана                                  0        0.0
# улица Юннатов                                  0        0.0
#
# [177 rows x 3 columns]

# %%
m = gdf_streets.explore("Кол-во КГИОП объектов", tiles=TILES)
m = territory.explore(m=m, style_kwds={"fill": False, "weight": 5})

m
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;head&gt;
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#
#         &lt;script&gt;
#             L_NO_TOUCH = false;
#             L_DISABLE_3D = false;
#         &lt;/script&gt;
#
#     &lt;style&gt;html, body {width: 100%;height: 100%;margin: 0;padding: 0;}&lt;/style&gt;
#     &lt;style&gt;#map {position:absolute;top:0;bottom:0;right:0;left:0;}&lt;/style&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.6.0/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-1.12.4.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://maxcdn.bootstrapcdn.com/bootstrap/3.2.0/js/bootstrap.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.6.0/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://maxcdn.bootstrapcdn.com/bootstrap/3.2.0/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://maxcdn.bootstrapcdn.com/bootstrap/3.2.0/css/bootstrap-theme.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://maxcdn.bootstrapcdn.com/font-awesome/4.6.3/css/font-awesome.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_13fe540f4c20e6c26bfd9f681b26c9aa {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#             &lt;/style&gt;
#
#
#                     &lt;style&gt;
#                         .foliumtooltip {
#
#                         }
#                        .foliumtooltip table{
#                             margin: auto;
#                         }
#                         .foliumtooltip tr{
#                             text-align: left;
#                         }
#                         .foliumtooltip th{
#                             padding: 2px; padding-right: 8px;
#                         }
#                     &lt;/style&gt;
#
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/d3/3.5.5/d3.min.js&quot;&gt;&lt;/script&gt;
#
#                     &lt;style&gt;
#                         .foliumtooltip {
#
#                         }
#                        .foliumtooltip table{
#                             margin: auto;
#                         }
#                         .foliumtooltip tr{
#                             text-align: left;
#                         }
#                         .foliumtooltip th{
#                             padding: 2px; padding-right: 8px;
#                         }
#                     &lt;/style&gt;
#
# &lt;/head&gt;
# &lt;body&gt;
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_13fe540f4c20e6c26bfd9f681b26c9aa&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#             var map_13fe540f4c20e6c26bfd9f681b26c9aa = L.map(
#                 &quot;map_13fe540f4c20e6c26bfd9f681b26c9aa&quot;,
#                 {
#                     center: [59.87088815, 30.4809201],
#                     crs: L.CRS.EPSG3857,
#                     zoom: 10,
#                     zoomControl: true,
#                     preferCanvas: false,
#                 }
#             );
#             L.control.scale().addTo(map_13fe540f4c20e6c26bfd9f681b26c9aa);
#
#
#
#
#
#             var tile_layer_12b715762a3cb8b475e87142a47066a2 = L.tileLayer(
#                 &quot;https://cartodb-basemaps-{s}.global.ssl.fastly.net/light_all/{z}/{x}/{y}.png&quot;,
#                 {&quot;attribution&quot;: &quot;\u0026copy; \u003ca href=\&quot;http://www.openstreetmap.org/copyright\&quot;\u003eOpenStreetMap\u003c/a\u003e contributors \u0026copy; \u003ca href=\&quot;http://cartodb.com/attributions\&quot;\u003eCartoDB\u003c/a\u003e, CartoDB \u003ca href =\&quot;http://cartodb.com/attributions\&quot;\u003eattributions\u003c/a\u003e&quot;, &quot;detectRetina&quot;: false, &quot;maxNativeZoom&quot;: 18, &quot;maxZoom&quot;: 18, &quot;minZoom&quot;: 0, &quot;noWrap&quot;: false, &quot;opacity&quot;: 1, &quot;subdomains&quot;: &quot;abc&quot;, &quot;tms&quot;: false}
#             ).addTo(map_13fe540f4c20e6c26bfd9f681b26c9aa);
#
#
#             map_13fe540f4c20e6c26bfd9f681b26c9aa.fitBounds(
#                 [[59.80486949999999, 30.3624536], [59.9369068, 30.5993866]],
#                 {}
#             );
#
#
#         function geo_json_a81ed20a29e63b72ef63b9f3e74ce2ac_styler(feature) {
#             switch(feature.id) {
#                 case &quot;23&quot;: case &quot;147&quot;: case &quot;171&quot;:
#                     return {&quot;color&quot;: &quot;#482475&quot;, &quot;fillColor&quot;: &quot;#482475&quot;, &quot;fillOpacity&quot;: 0.5, &quot;weight&quot;: 2};
#                 case &quot;30&quot;: case &quot;31&quot;: case &quot;60&quot;: case &quot;66&quot;: case &quot;79&quot;: case &quot;89&quot;: case &quot;99&quot;: case &quot;112&quot;: case &quot;123&quot;: case &quot;142&quot;: case &quot;150&quot;: case &quot;156&quot;:
#                     return {&quot;color&quot;: &quot;#470d60&quot;, &quot;fillColor&quot;: &quot;#470d60&quot;, &quot;fillOpacity&quot;: 0.5, &quot;weight&quot;: 2};
#                 case &quot;36&quot;: case &quot;50&quot;: case &quot;59&quot;: case &quot;110&quot;: case &quot;122&quot;: case &quot;129&quot;:
#                     return {&quot;color&quot;: &quot;#481a6c&quot;, &quot;fillColor&quot;: &quot;#481a6c&quot;, &quot;fillOpacity&quot;: 0.5, &quot;weight&quot;: 2};
#                 case &quot;47&quot;: case &quot;139&quot;: case &quot;170&quot;:
#                     return {&quot;color&quot;: &quot;#31688e&quot;, &quot;fillColor&quot;: &quot;#31688e&quot;, &quot;fillOpacity&quot;: 0.5, &quot;weight&quot;: 2};
#                 case &quot;70&quot;:
#                     return {&quot;color&quot;: &quot;#2ab07f&quot;, &quot;fillColor&quot;: &quot;#2ab07f&quot;, &quot;fillOpacity&quot;: 0.5, &quot;weight&quot;: 2};
#                 case &quot;86&quot;: case &quot;128&quot;: case &quot;131&quot;:
#                     return {&quot;color&quot;: &quot;#443983&quot;, &quot;fillColor&quot;: &quot;#443983&quot;, &quot;fillOpacity&quot;: 0.5, &quot;weight&quot;: 2};
#                 case &quot;106&quot;: case &quot;124&quot;: case &quot;162&quot;:
#                     return {&quot;color&quot;: &quot;#472f7d&quot;, &quot;fillColor&quot;: &quot;#472f7d&quot;, &quot;fillOpacity&quot;: 0.5, &quot;weight&quot;: 2};
#                 case &quot;132&quot;:
#                     return {&quot;color&quot;: &quot;#fde725&quot;, &quot;fillColor&quot;: &quot;#fde725&quot;, &quot;fillOpacity&quot;: 0.5, &quot;weight&quot;: 2};
#                 default:
#                     return {&quot;color&quot;: &quot;#440154&quot;, &quot;fillColor&quot;: &quot;#440154&quot;, &quot;fillOpacity&quot;: 0.5, &quot;weight&quot;: 2};
#             }
#         }
#         function geo_json_a81ed20a29e63b72ef63b9f3e74ce2ac_highlighter(feature) {
#             switch(feature.id) {
#                 default:

# %% [markdown]
# # Сохранение датафрейма в формате geojson

# %%
# Cохраняем датафрейм gdf_streets в файл streets_with_contains_kgiop.geojson в формате geojson
gdf_streets.to_crs("epsg:4326").to_file('streets_with_contains_kgiop.geojson', driver='GeoJSON')
gdf_streets.to_crs("epsg:4326").to_file('4326_streets_with_contains_kgiop.geojson', driver='GeoJSON')
